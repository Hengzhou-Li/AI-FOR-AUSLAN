# %% [markdown]
# **Copy the code to working folder**

# %%
! cp -r /kaggle/input/Auslan_Daily/Code/* ./
# Out:
# cp: cannot stat '/kaggle/input/Auslan_Daily/Code/*': No such file or directory

# %% [markdown]
# **Install the libraries**

# %%
# !pip install torch==1.11.0+cu102 torchvision==0.12.0+cu102 torchtext==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu102
# !pip install portalocker
# !pip install pyyaml
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu102
# ERROR: Could not find a version that satisfies the requirement torch==1.11.0+cu102 (from versions: 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1)
# ERROR: No matching distribution found for torch==1.11.0+cu102
# ...

# %% [markdown]
# **Modify**
# Tune parameter here

# %%
import yaml
yaml_file_path = '/kaggle/working/configs/sign_SP_RGB_Trans_E3D3.yaml'
with open(yaml_file_path, 'r') as file:
    config = yaml.safe_load(file)
config['training']['epochs'] = 40
config['model']['encoder']['num_layers'] = 3
with open(yaml_file_path, 'w') as file:
    yaml.safe_dump(config, file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3-649488963.py in <cell line: 0>()
#       1 import yaml
#       2 yaml_file_path = '/kaggle/working/configs/sign_SP_RGB_Trans_E3D3.yaml'
# ----> 3 with open(yaml_file_path, 'r') as file:
#       4     config = yaml.safe_load(file)
#       5 config['training']['epochs'] = 40
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/configs/sign_SP_RGB_Trans_E3D3.yaml'

# %% [markdown]
# **Train**

# %%
# !python -m signjoey train configs/sign_SP_RGB_Trans_E3D3.yaml
# Out:
# /usr/bin/python3: No module named signjoey

# %% [markdown]
# **Test**

# %%
# !python -m signjoey test configs/sign_SP_RGB_Trans_E3D3.yaml
# Out:
# /usr/bin/python3: No module named signjoey

# %% [markdown]
# **Translate**

# %%
# !python -m signjoey translate configs/sign_SP_RGB_Trans_E3D3.yaml
# Out:
# /usr/bin/python3: No module named signjoey

# %% [markdown]
# **Submission**
# Result was saved to 'Auslan_Daily/Code/sign_SP_RGB_Trans_E3D3/test_hyp.csv'
# Remeber to change the name of the csv file to 'submission.csv' before you submit
# Check your result and upload it via http://codingfest.top/
